# %% [markdown]
# # Test Installation — LangChain & LangGraph
#
# Quick sanity check to confirm `langchain` and `langgraph` are installed correctly in this environment.

# %%
from langgraph.graph import StateGraph
